# %% [markdown]
# <a href="https://colab.research.google.com/github/STLNFTART/MotorHandPro/blob/main/notebooks/visualization/01_comprehensive_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comprehensive Visualization Suite
#
# Complete visualization examples for Primal Logic:
# - Time series plots
# - Heatmaps
# - 3D visualizations
# - Interactive plots

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip install numpy matplotlib pandas
    # !git clone https://github.com/STLNFTART/MotorHandPro.git
    sys.path.append('/content/MotorHandPro')
else:
    sys.path.append('..' if 'notebooks' not in str(Path.cwd()) else '../..')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Visualization Examples

# %%
import seaborn as sns

# Generate sample data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure(figsize=(14, 5))

# 3D surface
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(X, Y, Z, cmap='viridis')
ax1.set_title('3D Surface Plot', fontweight='bold')

# Heatmap
ax2 = fig.add_subplot(122)
im = ax2.contourf(X, Y, Z, levels=20, cmap='viridis')
plt.colorbar(im, ax=ax2)
ax2.set_title('2D Heatmap', fontweight='bold')

plt.tight_layout()
plt.show()
