# %% [markdown]
# <a href="https://colab.research.google.com/github/STLNFTART/MotorHandPro/blob/main/notebooks/tutorials/03_multi_language_guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Language Programming Guide
#
# Comprehensive guide to programming in APL, Python, Prolog, and D.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip install numpy matplotlib pandas
    # !git clone https://github.com/STLNFTART/MotorHandPro.git
    sys.path.append('/content/MotorHandPro')
else:
    sys.path.append('..' if 'notebooks' not in str(Path.cwd()) else '../..')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Language Comparison

# %%
languages = {
    'Python': {'strength': 'Rapid prototyping', 'use_case': 'Data analysis, ML'},
    'APL': {'strength': 'Array operations', 'use_case': 'Mathematical modeling'},
    'Prolog': {'strength': 'Logic reasoning', 'use_case': 'Compliance, planning'},
    'D': {'strength': 'Performance', 'use_case': 'Real-time control'}
}

for lang, info in languages.items():
    print(f'{lang}:')
    print(f'  Strength: {info["strength"]}')
    print(f'  Use case: {info["use_case"]}')
    print()
