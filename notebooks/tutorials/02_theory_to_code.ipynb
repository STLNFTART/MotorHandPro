# %% [markdown]
# <a href="https://colab.research.google.com/github/STLNFTART/MotorHandPro/blob/main/notebooks/tutorials/02_theory_to_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # From Theory to Implementation
#
# Translating mathematical theory into working code across multiple languages.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip install numpy matplotlib pandas
    # !git clone https://github.com/STLNFTART/MotorHandPro.git
    sys.path.append('/content/MotorHandPro')
else:
    sys.path.append('..' if 'notebooks' not in str(Path.cwd()) else '../..')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Mathematical Theory

# %%
print('Mathematical Formula:')
print('ψ = e + λ * Ec')
print('Ec = decay * Ec + e * dt')
print('γ = D * (1 - exp(-|ψ|/D))')
print('\nImplementation in Python:')
print('''
class PrimalLogic:
    def update(self, error, dt):
        decay = np.exp(-self.lambda_val * dt)
        self.Ec = decay * self.Ec + error * dt
        psi = error + self.lambda_val * self.Ec
        gamma = DONTE * (1 - np.exp(-abs(psi) / DONTE))
        return psi, gamma
''')
