# %% [markdown]
# <a href="https://colab.research.google.com/github/STLNFTART/MotorHandPro/blob/main/notebooks/nasa/04_crew_health_dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crew Health Dashboard
#
# Real-time astronaut health monitoring and analysis.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip install numpy matplotlib pandas
    # !git clone https://github.com/STLNFTART/MotorHandPro.git
    sys.path.append('/content/MotorHandPro')
else:
    sys.path.append('..' if 'notebooks' not in str(Path.cwd()) else '../..')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Cloning into 'MotorHandPro'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 6987 (delta 216), reused 200 (delta 178), pack-reused 6715 (from 1)
# Receiving objects: 100% (6987/6987), 62.48 MiB | 21.13 MiB/s, done.
# Resolving deltas: 100% (1370/1370), done.
# Updating files: 100% (6414/6414), done.

# %% [markdown]
# ## Health Metrics Simulation

# %%
def simulate_health_metrics(days=500):
    t = np.arange(days)
    # Various health metrics
    heart_rate = 70 + 5 * np.sin(t / 30) + np.random.randn(days) * 2
    bone_density = 100 - 0.01 * t + np.random.randn(days) * 0.5
    muscle_mass = 100 - 0.02 * t + np.random.randn(days) * 0.5
    return t, heart_rate, bone_density, muscle_mass

t, hr, bd, mm = simulate_health_metrics()

fig, axes = plt.subplots(3, 1, figsize=(14, 10))
axes[0].plot(t, hr, 'r-', alpha=0.7)
axes[0].set_ylabel('Heart Rate (bpm)')
axes[0].set_title('Heart Rate Monitor', fontweight='bold')
axes[0].grid(True, alpha=0.3)

axes[1].plot(t, bd, 'b-', alpha=0.7)
axes[1].set_ylabel('Bone Density (%)')
axes[1].set_title('Bone Density', fontweight='bold')
axes[1].grid(True, alpha=0.3)

axes[2].plot(t, mm, 'g-', alpha=0.7)
axes[2].set_xlabel('Mission Day')
axes[2].set_ylabel('Muscle Mass (%)')
axes[2].set_title('Muscle Mass', fontweight='bold')
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
